# %% [markdown]
# <a href="https://colab.research.google.com/github/Amritanshu005/Python_campusX/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Print

# %%
print("hello World")

# %%
print(7)

# %%
print(4,4)

# %%
print(true)

# %%
print("hello",1,4.4,True)

# %%
print("hello",1,2.3,False,sep='/')

# %%
print('hello')
print('Amrit')

# %%
print('hello',end='_')
print('world')

# %% [markdown]
# Data Types

# %%
# Integer
print(8)
#  110^308
print(1e308)

# %%
# Decimal/Float
print(8.55)
print(1.7e308)

# %%
# Boolean
print(True)
print(False)

# %%
# String
print('Hello World')

# %%
# List-> C->Array
print([1,2,3,4,5])

# %%
# Tuple
print((1,2,3,4,5))

# %%
# sets
print({1,2,3,4,5})

# %%
# Dictionary
print({'name':'Nitish','gender':'Male','weight',:70})

# %%
# type
type(3)
type(3.5)
type(6+6j)
type({1,2,3,4,5})

# %% [markdown]
# Variables

# %%
name="Amrit"
print(name)
a=5
b=6
print(a+b)

# %%
# dynamic Typing
# a=5
# a=5.5
a="amrit"
# we can reassign values in a of different data types

# Static typing
# int a=5
# python doesnot support static typing

# %%
# Dynamic Binding
a=5
print(a)
a="amrit"
print(a)

# Static Binding
# int a = 5;

# in dynamic binding you can reasign values .. But if you use dynamic binding you cannot do that ... as there datatype is fixed

# %%
a=1
b=2
c=3
print(a,b,c)

# %%
a,b,c=1,2,3
print(a,b,c)

# %%
a=b=c=5
print(a,b,c)

# %% [markdown]
# **Keywords**

# %%
# reserve keywords by python
# Flase, None, True, and, as, assert, break, class, continue,
# def, del, elif, else, except, finally, for, from, global,
# if, import, in, is, lambda, nonlocal, not, or, pass, raise, return,
# try, while, with, yield, help

# %% [markdown]
# **Identifiers**

# %%
# You can't start with a digit
# 1name='amrit' ❌
name1='amrit'✅
# you can only use(_)underscore as special charcter
_="amrit"
print(_)#this is valid
# identifiers can not be keywords

# %% [markdown]
# User Input

# %%
input("Enter Email ")
# Out:
# Enter Email anshuamrit005@gmail.com
# 'anshuamrit005@gmail.com'

# %% [markdown]
# take two numbers from user and add them

# %%
# take two integer input from user and store it
fnum=input("Enter 1st number ")# universal input is str
snum=input("Enter second number")# it will treat input as str
# now add both number and store them
result=fnum+snum
print(type(result))# traeting result as string
print(result)

fnum=int(input("Enter 1st number"))
snum=int(input("Enter 2nd number"))
result=fnum+snum
print(result)
print(type(result))
# or result=int(fnum)+int(snum) #that will also work
# but that after type checking type(fnum)--> it will show string
# Out:
# Enter 1st number 44
# Enter second number56
# <class 'str'>
# 4456
# Enter 1st number44
# Enter 2nd number56
# 100
# <class 'int'>

# %% [markdown]
# Type Converstion

# %%
# Implicit
print(5+5.6)
# answer will come in float
# that means python is halndling int and float internally and converting it into float...which is mathematically true
# So Impicit type conversion is only possible where it is mathematically true
# print(3+'4')❌
# this one will show error as datatype string and datatype int can't be added mathematically

# %%
# Explicit
a='4'
b=5
c=int(a)
print(c+b)
# in explicit hum bahar se batate ki humko kon se data type mai humara answer chahaiye

# string
e=5
d=str(e)
print(d)
print(type(d))

# float
float(4)
# Out:
# 9
# 5
# <class 'str'>
# 4.0

# %% [markdown]
# **Literals**

# %%
z=2
# a-->variable
# =-->operator
# 2-->literals

a=0b1010 #Binary Literals
b=100 # Decimal Literals
c=0o310 #Octal Literals
d=0x12c #Hexadecimal Literals

# Float Literal
float_1=10.5
float_2=1.5e2 #==> 1.5*10^3-->1500.0
float_3=1.5e-3 #==> 1.5*10^-3-->0.0015

# Complex Literal
x=3.14j

print(a,b,c,d, float_1, float_2, float_3, x, x.imag, x.real)
# Out:
# 10 100 200 300 10.5 150.0 0.0015 3.14j 3.14 0.0

# %%
# String
s='String can be writtten in single quote.'
s1="String can also be written in double quote."
s2="""String can also be written in tripple quote."""
s3='C'#you can store a single charcter as well.

# Emoji
unicode=u"\U0001f600\U0001F606\U0001F923" # datatype is string
raw_str=r"raw \n string"# that(r) helps you write(\n) in string
raw_str="raw \n string" #esse line \n lagne se line change ho jata hai
print(s)
print(s1)
print(s2)
print(s3)
print(unicode)
print(raw_str)
# Out:
# String can be writtten in single quote.
# String can also be written in double quote.
# String can also be written in tripple quote.
# C
# 😀😆🤣
# raw
#  string

# %%
# Boolean
# internally True=1, Flase=0
# so app boolean ke sath mathmatical function v try kar sakte ho
a=True+4
b=10-True
c=10-False

print("a:",a)
print("b:",b)
print("c:",c)
# Out:
# a: 5
# b: 9
# c: 10

# %%
# None
a= None
print(a)

# %% [markdown]
# **Operators**

# %%
# Arithmetric Operators
print(5+6) #addition
print(5-6) #substaction
print(5*6) #multiplication
print(5/2) #division
print(5//2) #integer division
print(5%2) #modulas-->reminder
print(5**2) #power off-->5 to the power 2

# %%
#Reational Operators
print(4<5)
print(4>=4)
print(4<=4)
print(4==4)
print(4!=4)

# %%
# Logical Operators
print(1 and 0) #0
print(1 or 0) #1
print(not 1) #0-->False

# %%
#Bitwise Operators
#bitwise and
print(2&3) #2 --> 2->010, 3->110, dono mai & lagaoge then we get 010 i.e, 2

# biwise or
print(2|3) #3 -->2->010, 3->110, dono mai or lagaoge then we get 110 i.e, 3

# bitwise xor
print(2^3) #1 -->2->010, 3->110, dono mai xor lagaoge then we get 100 i.e, 1
# xor gives true when input are different.

# bitwise not
print(~2)

# leftsift
print(4>>2)

# rightsift
print(5<<2)
# Out:
# 2
# 3
# 1
# -3
# 1
# 20

# %%
# assignment Operators
#  =
a=2
# a=a+2
# a+=2
# a-=2
# a*=2
# a/=2
# a%=2
print(a)
# Out:
# 2

# %%
# Membership Operators
# in/not in
print('D' in 'Delhi') # casesensative
print("d" not in "Delhi")
# works on String, int, touple, dictionary, array
# Out:
# True
# True

# %%
# Program - Find the sum of a 3 digit number entered by the user
number = int(input("Enter 3 digit number"))
# If user enters 456
# a=6
a=number%10
# number=45
number=number//10
# b=5
b=number%10
# number=4
number=number//10
# c=4
c=number
print(a+b+c)
# Out:
# Enter 3 digit number456
# 15

# %% [markdown]
# **If-else in Python**

# %%
# login program and indentation
# email-> anshuamrit@gmail.com
# password->1234

email=input('enter email')
password=input('enter password')

if (email=='anshuamrit@gmail.com' and password=='1234'):{
  print('welcome')}
else:{
  print('wrong credentials')}
# Out:
# enter emailanshuamrit@gmail.com
# enter password1234
# welcome

# %%
email=input('enter email')
password=input('enter password')

if email=='anshuamrit@gmail.com' and password=='1234':
  print('welcome')
elif email=='anshuamrit@gmail.com' and password !='1234':
  print('wrong password')
  password=input("enter password again")
  if password=='1234':
    print('welcome')
  else:
    print("tumse na ho paeyga!")

else:
  print('wrong credentials')

# %%
# min among all three
a=int(input('enter 1st number'))
b=int(input('enter 2nd number'))
c=int(input('enter 3rd number'))

if a<b and a<c:
  print('a is smallest')
elif b<c:
  print('b is smallest')
else:
  print('c is smallest')
# Out:
# enter 1st number345
# enter 2nd number234
# enter 3rd number111
# c is smallest

# %%
# max among all three
a=int(input('enter 1st number '))
b=int(input('enter 2nd number '))
c=int(input('enter 3rd number '))

if a>b and a>c:
  print('a is largest',a)
elif b>c:
  print('b is largest',b)
else:
  print('c is largest',c
        )
# Out:
# enter 1st number 5
# enter 2nd number 5
# enter 3rd number 5
# c is largest 5

# %%
# menue driven code
fnum = int(input("enter 1st number"))
snum = int(input("enter 2nd number"))

op=input("enter operations among'+,-,* and /'")
if op=="+":
  print(fnum+snum)
elif op=="-":
  print(fnum-sum)
elif op=="*":
  print(fnum*snum)
elif op=="/":
  print(fnum/snum)
else:
  print("enter valid operations")
# Out:
# enter 1st number3
# enter 2nd number2
# enter operations among'+,-,* and /'/
# 1.5

# %%
# menu driven calculator
menu=input(""" hi how can I help you!
1. Enter 1 to change pin
2. Enter 2 for balance check
3.Enter 3 for withdrawl
4.Enter 4 for exit""")
if menu =="1":
  print("pin changed")
elif menu=="2":
  print("balance checked")
elif menu =="3":
  print(" Amount withdraw")
else:
  print("you are out of the Program! ")

# %% [markdown]
# **Modules in Python**
#
#
# *   math
# *   keywords
# *   random
# *   datetime

# %%
# math
import math
a=math.factorial(5) #120
b=math.floor(6.8) #6
c=math.sqrt(25) #5.0
print(a,b,c)
# Out:
# 120 6 5.0

# %%
# keywords
import keyword
print(keyword.kwlist) # prints all reserve keywords
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# random
import random
print(random.randint(1,100))
# Out:
# 68

# %%
# datetime
import datetime
print(datetime.datetime.now())
# Out:
# 2026-07-27 06:07:01.563641

# %%
# want to check what kind moudles python have
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# /usr/local/lib/python3.12/dist-packages/Cryptodome/SelfTest/PublicKey/test_ECC_NIST.py:779: UserWarning: Warning: skipping extended tests for P-192 tests from point-at-infinity.org
#   tv_pai = load_test_vectors(("PublicKey", "ECC"),
# /usr/local/lib/python3.12/dist-packages/Cryptodome/SelfTest/PublicKey/test_ECC_NIST.py:800: UserWarning: Warning: skipping extended tests for P-224 tests from point-at-infinity.org
#   tv_pai = load_test_vectors(("PublicKey", "ECC"),
# /usr/local/lib/python3.12/dist-packages/Cryptodome/SelfTest/PublicKey/test_ECC_NIST.py:821: UserWarning: Warning: skipping extended tests for P-256 tests from point-at-infinity.org
#   tv_pai = load_test_vectors(("PublicKey", "ECC"),
# /usr/local/lib/python3.12/dist-packages/Cryptodome/SelfTest/PublicKey/test_ECC_NIST.py:842: UserWarning: Warning: skipping extended tests for P-384 tests from point-at-infinity.org
# ...
